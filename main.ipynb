# %%
import pandas as pd
import numpy as np

data = {
    "Name": ["Alice", "Bob", "Chris"],
    "Age": [20, 19, 18],
    "Score": [89, 93, 87]
}

table = pd.DataFrame(data)

print(table)
# Out:
#     Name  Age  Score
# 0  Alice   20     89
# 1    Bob   19     93
# 2  Chris   18     87

# %%
x = 1 + 1
print(x)
# Out:
# 2
