# %%
import pandas as pd
import numpy as np

data = {
    "Name": ["Alice", "Bob", "Chris"],
    "Age": [20, 19, 18],
    "Score": [89, 93, 87]
}

table = pd.DataFrame(data)

print(table)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       4 data = {
#       5     "Name": ["Alice", "Bob", "Chris"],
#       6     "Age": [20, 19, 18],
#       7     "Score": [89, 93, 87]
#       8 }
#
# ModuleNotFoundError: No module named 'pandas'

# %%
x = 1 + 1
print(x)
# Out:
# 2
